# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s = pd.Series([1,2,3,4],index = ['a','b','c','d'])
s
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
data = [[1,444,'abc'],
[2,555,'def'],
[3,666,'ghi'],
[4,444,'xyz']]
df = pd.DataFrame(data,columns = ["Idx","std_id","depart"])
df
# Out:
#    Idx  std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    ghi
# 3    4     444    xyz

# %%
data = {"Idx":[1,2,3,4],
"std_id":[444,555,666,777],
"depart":['abc','def','xyz','ghi']}
df = pd.DataFrame(data)
df
# Out:
#    Idx  std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    xyz
# 3    4     777    ghi

# %%
display(df)
colums = ['idx-1','std_id1','dep']
index = ['a','b','c','d']
df.columns = colums
df.index = index
display(df)
# Out:
#    idx-1  std_id1  dep
# 0      1      444  abc
# 1      2      555  def
# 2      3      666  xyz
# 3      4      777  ghi
#    idx-1  std_id1  dep
# a      1      444  abc
# b      2      555  def
# c      3      666  xyz
# d      4      777  ghi

# %%
#df.dtypes
df['idx-1'].dtype
# Out:
# dtype('int64')

# %%
df['std_id1'] = df['std_id1'].astype('category')
df.dtypes
# Out:
# idx-1         int64
# std_id1    category
# dep             str
# dtype: object

# %%
cols = ['idx-1', 'dep']
df[cols] = df[cols].astype('category')
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 2
#       1 cols = ['idx-1', 'dep']
# ----> 2 df[cols] = df[cols].astype('category')
#       3 df.dtypes
#
# File ~\Desktop\DEPI_AI\DEPI-AMIT-R5-AI\.venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~\Desktop\DEPI_AI\DEPI-AMIT-R5-AI\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
# ...

# %%
data = {"Idx":[1,2,3,4],
"std_id":[444,555,666,777],
"depart":['abc','def','xyz','ghi']}
df = pd.DataFrame(data)
df
# Out:
#    Idx  std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    xyz
# 3    4     777    ghi

# %%
df.head()
# Out:
#    Idx  std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    xyz
# 3    4     777    ghi

# %%
df.tail(1)
# Out:
#    Idx  std_id depart
# 3    4     777    ghi

# %%
df.describe()
# Out:
#             Idx      std_id
# count  4.000000    4.000000
# mean   2.500000  610.500000
# std    1.290994  143.300384
# min    1.000000  444.000000
# 25%    1.750000  527.250000
# 50%    2.500000  610.500000
# 75%    3.250000  693.750000
# max    4.000000  777.000000

# %%
df.columns
# Out:
# Index(['Idx', 'std_id', 'depart'], dtype='str')

# %%
df['std_id'].unique()
df['std_id'].nunique()
# Out:
# 4

# %%
df['std_id'].max()
df['std_id'].idxmax()
# Out:
# 3

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Idx     4 non-null      int64
#  1   std_id  4 non-null      int64
#  2   depart  4 non-null      str
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes

# %%
d = df['depart'].value_counts()
d
# Out:
# depart
# abc    1
# def    1
# xyz    1
# ghi    1
# Name: count, dtype: int64

# %%
df['std_id'].sum()
# Out:
# np.int64(2442)

# %%
df['depart'].values
# Out:
# <StringArray>
# ['abc', 'def', 'xyz', 'ghi']
# Length: 4, dtype: str

# %%
df.values
# Out:
# array([[1, 444, 'abc'],
#        [2, 555, 'def'],
#        [3, 666, 'xyz'],
#        [4, 777, 'ghi']], dtype=object)

# %%
x = df.values
type(x)
# Out:
# numpy.ndarray

# %%
df1 = df.replace(555,"shahd",inplace =True)
df
# Out:
#    Idx std_id depart
# 0    1    444    abc
# 1    2  shahd    def
# 2    3    666    xyz
# 3    4    777    ghi

# %%
df.std_id = df.std_id.map({444:"ytrff",888:"dddd"})
df
# Out:
#    Idx std_id depart
# 0    1  ytrff    NaN
# 1    2    NaN    NaN
# 2    3    NaN    NaN
# 3    4    NaN    NaN

# %%
df.depart.iloc[2]
# Out:
# nan

# %%
data = {"Idx":[1,2,3,4],
"std_id":[444,555,666,777],
"depart":['abc','def','xyz','ghi']}
df = pd.DataFrame(data)
df
# Out:
#    Idx  std_id depart
# 0    1     444    abc
# 1    2     555    def
# 2    3     666    xyz
# 3    4     777    ghi

# %%
x = df.iloc[:, 0:2]
y = df.iloc[:, -1]
