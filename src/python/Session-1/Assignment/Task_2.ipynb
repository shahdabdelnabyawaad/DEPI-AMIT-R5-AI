# %%
'''Task-2: 
Encoded Message: 

Steps to Decode: 
1. Extract the core part of the message: "mocleW EPGTQ". 
2. Reverse the first word: "mocleW" becomes "Welcome". 
3. Replace shifted vowels in the second word: 
o "EPGTQ": No vowels to change. 
4. Final decoded message: "Welcome PGTQ". '''

# %%
x="###!!@mocleW EPGTQ!!!6789 "
y=x.split("@")
#print(y) بجرب شكلها هيبقي عامل ازاي وبعد ما خلصت عملتلها هاش علشان النتيجه بس تبقي ظاهره

print(y[1].split("!!!")[0])
# Out:
# mocleW EPGTQ

# %%
word="mocleW"
print(word[::-1])
# Out:
# Welcom

# %%
second_word="EPGTQ"
print(second_word.replace("E"," "))
# Out:
#  PGTQ
