# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello World")   # print a  welcome message

# %%
'''print("Hello World")
print("Hello World")
print("Hello World")
print("Hello World")
print("Hello World")
print("Hello World")
print("Hello World")
print("Hello World")
'''
print("Hello World")
# Out:
# Hello World

# %%
print("My name is {0},and my age is {1}".format("shahd",21))
print("My name is {0},and my age is {1}".format("ALI",21))
# Out:
# My name is shahd,and my age is 21
# My name is ALI,and my age is 21

# %%
name = "shahd"
age = 21
print(f"my name is {name}, and my age is {age}")
# Out:
# my name is shahd, and my age is 21

# %%
name="Shahd Abdelnaby"
age=21
course_name="ML and AI"

print("My name is {0},My age is {1},Course_name{2}".format(name,age,course_name))
# Out:
# My name is Shahd Abdelnaby,My age is 21,Course_nameML and AI

# %%
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
x="true"
print(type(x))
# Out:
# <class 'str'>

# %%
colors = {"Red", "Blue", "Red"}

print(colors)
# Out:
# {'Blue', 'Red'}

# %%
name="Amit Learning"
print(name[0])
print(name[-1])
print(name[0:4:1])
# Out:
# A
# g
# Amit

# %%
name="shahd abdelnaby"
print(name[6::1])
# Out:
# abdelnaby

# %%
name="Shahd Abdelnaby"
print(name.upper())
print(name.lower())
print(name.capitalize())
print(name.replace("Shahd","Mohamed"))
print(name.title())
print(name.swapcase())
print(name.count("Shahd"))
print(name.split())
# Out:
# SHAHD ABDELNABY
# shahd abdelnaby
# Shahd abdelnaby
# Mohamed Abdelnaby
# Shahd Abdelnaby
# sHAHD aBDELNABY
# 1
# ['Shahd', 'Abdelnaby']

# %%
name_1=["Shahd","Abdelnaby","Awaad","Gooda"]
sentance=" ".join(name_1)
print(sentance)
# Out:
# Shahd Abdelnaby Awaad Gooda

# %%
my_name="Shahd Abdelnaby "
print(my_name.startswith("Shahd"))
print(my_name.endswith("w"))
# Out:
# True
# False

# %%
print("Amit\n Learning")
# Out:
# Amit
#  Learning

# %%
print("Amit\tLearning")
# Out:
# Amit	Learning

# %%
print("Amit\"Learning\"")
# Out:
# Amit"Learning"

# %%
print("Amit\\ Learning")
# Out:
# Amit\ Learning

# %%
print("HelloS\b")
# Out:
# Hello
