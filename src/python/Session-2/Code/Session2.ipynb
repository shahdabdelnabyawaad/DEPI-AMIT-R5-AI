# %%
list_one=[1,2,3,4,"DEPI","machine learning",True,[1,2,3,4,"true",["ml","dl","llm"]]]
print(type(list_one))
# Out:
# <class 'list'>

# %%
print(list_one[4])
# Out:
# DEPI

# %%
list_one=[1,2,3,4,"DEPI","machine learning",True,[1,2,3,4,"true",["ml","dl","llm"]]]
list_one[7][5][0]
# Out:
# 'ml'

# %%
list_1=["Depi","am","AI"]
list_1.append("DEEP")
print(list_1)
# Out:
# ['Depi', 'am', 'AI', 'DEEP']

# %%
 number = [1,2,3]
 number.append(4)
 print(number)
# Out:
# [1, 2, 3, 4]

# %%
list_1.insert(0,"Shahd")

# %%
print(list_1)
# Out:
# ['Shahd', 'Depi', 'am', 'AI', 'DEEP']

# %%
list_1.extend(list_one)
list_1
# Out:
# ['Shahd',
#  'Depi',
#  'am',
#  'AI',
#  'DEEP',
#  1,
#  2,
#  3,
#  4,
#  'DEPI',
#  'machine learning',
#  True,
#  [1, 2, 3, 4, 'true', ['ml', 'dl', 'llm']]]

# %%
_1=[4,5]
_2=[4,6,[5,10]]
_1.extend(_2)
_1
# Out:
# [4, 5, 4, 6, [5, 10]]

# %%
list_1.remove("DEPI")
list_1
# Out:
# ['Shahd',
#  'am',
#  'AI',
#  'DEEP',
#  1,
#  2,
#  3,
#  'machine learning',
#  True,
#  [1, 2, 3, 'true', ['ml', 'dl', 'llm']],
#  1,
#  2,
#  3,
#  'DEPI',
#  'machine learning',
#  True,
#  [1, 2, 3, 'true', ['ml', 'dl', 'llm']]]

# %%
list_2=["depi","ml","ai"]
list_2.pop()
list_4=[1,2,3]
list_4.append(list_2)
print(list_2)
print(list_4)
# Out:
# ['depi', 'ml']
# [1, 2, 3, ['depi', 'ml']]

# %%
del list_2[0]
print(list_2)
# Out:
# ['ml']

# %%
input_list = ["amit","learning","machine learning","data science","deep learning"]
item = input("Enter the item to delete: ")
input_list.remove(item)
print(input_list)
# Out:
# ['amit', 'learning', 'machine learning', 'deep learning']

# %%
my_list=[1,2,3,4,5]
index_of_2=my_list.index(2)
print(index_of_2)
# Out:
# 1

# %%
my_list=[1,2,3,2,4,2]
count_of_2=my_list.count(2)
print(count_of_2)
# Out:
# 3

# %%
my_list=[4,7,3,2,1]
my_list.sort()
print(my_list)
# Out:
# [1, 2, 3, 4, 7]

# %%
my_list=[3,4,2,1,5]
my_list.reverse()
print(my_list)
# Out:
# [5, 1, 2, 4, 3]

# %%
my_list=[1,2,3,4,5]
my_list.clear() #  = del my_list[:]
print(my_list)
# Out:
# []

# %%
tuple_1=(1,2,3)
print(tuple_1)
# Out:
# (1, 2, 3)

# %%
type(tuple_1)
# Out:
# tuple

# %%
my_dict = {"key": 12.4, "key2": 5}
my_dict["key"] = "shahd"
print(my_dict)
# Out:
# {'key': 'shahd', 'key2': 5}

# %%
print(my_dict["key"])
# Out:
# 12.4

# %%
value = [("a", 1), ("b", 2), ("c", 3)]
my_dict = dict(value)
print(my_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
num= int(input("Enter a number: "))
print(num)
print(type(num))
# Out:
# 5
# <class 'int'>

# %%
2==3
# Out:
# False

# %%
3==3
# Out:
# True

# %%
a=10
b=20
a is b
# Out:
# False

# %%
c=3
j=2
l=c % j
print(l)
# Out:
# 1

# %%
num_1=int(input("Enter a number 1: "))
num_2=int(input("Enter a number 2: "))
y=num_1+num_2
x= num_1-num_2
z= num_1*num_2
print(y)
print(x)
print(z)
# Out:
# 5
# -1
# 6

# %%
a=10
b=20
if a>b:
    print("a is greater than b")
else:
    print("b is greater than a")
# Out:
# b is greater than a

# %%
x=5
y=10
if x>0 and y>0:
    print("both x and y are positive numbers")
# Out:
# both x and y are positive numbers

# %%
degree = int(input("Enter your degree: "))
if  90<= degree <=100:
    print("A")
elif 80<= degree <90:
    print("B")

elif 70<=degree <80:
    print("C")
elif 60<= degree <70:
    print("D")
elif 0<= degree<60:
    print("F")       
else:
    print("Invalid degree")
# Out:
# Invalid degree
