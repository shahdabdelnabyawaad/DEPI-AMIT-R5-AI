# %%
"""




"""



class StudentInfo:   # attribute
    name = "Shahd Abdelnaby"
    age = 21

    def std_info(self):  # method
       # print ("my name is Shahd")
        print(self)

# %%
s1=StudentInfo() # object
print(s1) # memmory address of object
s1.std_info()  # كده عطاني نفس ال memmory address بتاع ال object

# %%
s1 = StudentInfo()
s1.age =30
s1.name = "Shahoda"
print(s1.age)
print(s1.name)
s1.std_info()
# Out:
# 30
# Shahoda
# my name is Shahd

# %%
s1.std_info() # هوا بيقول عاوز argument ولكن احنا محطناش حاجه
# Out:
# my name is Shahd

# %%
class Student:
    def __init__(self, name:str="test", age:int=20)->str:
        self.name = name
        self.age = age

    def std_info(self):
        print(self.name)
        print(self.age)

# %%
print(dir(list))
lst1 = [1,2,3,4,5]
lst1.clear()
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
from abc import ABC ,abstractmethod

class Animal(ABC):
    @abstractmethod
    def move(self):
        pass
class Bird(Animal):
    def move(self):
        print("move from bird")

class Cat(Animal):
    def move(self):
        print("move from cat")

a = Bird()
a.move()
# Out:
# move from bird

# %%
class Employee:
    def __init__(self,name, salary):
        self.name = name
        self.salary = salary

    def set_salary(self,obj,new_sal):
        obj.salary = new_salary

class Manager:

    def __init__(self,name,salary):

        self.name = name
        self.salary =salary

# %%
E1 =Employee("Depi",2000)
m1 = Manager("Shahd",8000)
E1.set_salary(m1,6000)
print(m1._salary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 3
#       1 E1 =Employee("Depi",2000)
#       2 m1 = Manager("Shahd",8000)
# ----> 3 E1.set_salary(m1,6000)
#       4 print(m1._salary)
#
# Cell In[44], line 7, in Employee.set_salary(self, obj, new_sal)
#       6     def set_salary(self,obj,new_sal):
# ----> 7         obj.salary = new_salary
#
# NameError: name 'new_salary' is not defined

# %%
class A():
    def do_this(self):
        print("I am in A")
class B(A):
    pass
class C():
    def do_this(self):
        print("Iam in C")  
class D(B,C):
    pass

x = D()
x.do_this()
# Out:
# I am in A

# %%
class A():
    def do_this(self):
        print("I am in A")
class B(A):
    pass
class C():
    def do_this(self):
        print("I am in C")  
class D(C,B):
    pass

x = D()
x.do_this()
# Out:
# I am in C

# %%
 class Calc:
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def sum (self):
        return self.x + self.y    
    def sub (self):
        return self.x - self.y
    def mul(self):
        return self.x * self.y
    def div(self):
        return self.x / self.y

# %%
from calc import Calc
if __name__ == "__main__":
            

                    print("Hello")
                    c= Calc(10,20)
                    print(c.sum())
                    print(c.sub())
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:3748 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[61], line 1
#     from calc import Calc
#
#   File c:\Users\shahd\Desktop\DEPI_AI\DEPI-AMIT-R5-AI\src\python\Session-5\Code\calc.py:1
#     class Calc:
#     ^
# IndentationError: unexpected indent
